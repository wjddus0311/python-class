# %%
nums=[10,20,30,40,50]
for i in range(5):
  print(nums[i])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
s=0
num=[10,20,30,40,50]
for i in range(5):
  s+=num[i]
print(s)
# Out:
# 150

# %%
s=0
num=[10,20,30,40,50]
for i in num:
  s+=i
print(s)
# Out:
# 150

# %%
num=[12,20,18,15,13,11]

for i in range(len(num)):
  if num[i]%2==0:
    print(num[i],end=' ')
# Out:
# 12 20 18

# %%
num=[12,20,18,15,13,11]
for i in num:
  if i%2==0:
    print(i,end=' ')
# Out:
# 12 20 18

# %%
num=[10,20,30,40,78]
e=0
for i in range(len(num)):
  if num[i]>e:
    e=num[i]
print(e)
# Out:
# 78

# %%
num=[10,20,30,40,78]
e=0
for i in num:
  if i>e:
    e=i
print(e)
# Out:
# 78

# %%
a=[70,85,60,90,75]
c=0
for i in range(len(a)):
  c+=a[i]
avg=c/len(a)
print(avg)
for j in a:
  if j>avg:
    print(j,end=' ')
# Out:
# 76.0
# 85 90

# %%
a=[70,85,60,90,75]
c=0
for i in a:
  c+=i
avg=c/len(a)
print(avg)
for j in a:
  if j>avg:
    print(j,end=' ')
# Out:
# 76.0
# 85 90

# %%
a=[10,20,30,40,50,60]
for i in range(len(a)):
  if i%2==0:
    print(a[i],end=' ')
# Out:
# 10 30 50

# %%
a=[5,7,3,8,10]

for i in range(1, len(a)):
    if a[i] > a[i-1]:
        print(a[i],end=' ')
# Out:
# 7 8 10

# %%
a = [10, 15, 13, 20]

for i in range(len(a) - 1):
    d = a[i+1] - a[i]
    print(d,end=' ')
# Out:
# 5 -2 7

# %%
a=[1,2,3,4]
for i in range(len(a)-1,-1,-1):
  print(a[i],end=' ')
# Out:
# 4 3 2 1
