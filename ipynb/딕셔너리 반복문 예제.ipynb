# %%
a={'a':5,'b':3,'c':6}
total=0
for i in a:
  total+=a[i]
print(total)
# Out:
# 14

# %%
nu=int(input('프로그램 반복 할 횟수 정하기'))
for n in range(nu):
  a=int(input('인원 입력'))
  c={}
  ma=0
  for i in range(a):
    b=input().split()
    n=b[0]
    count=int(b[1])
    c[n]=count
    t_b=sum(c.values())
    avg=t_b/a     
  print(avg)

  a_s=[]
  for k in c:
    if c[k] >= avg:
          a_s.append(k)
  print(a_s)

  for j in c:
    if c[j]>ma:
      ma=c[j]
      top=j
  print(top,ma)
  print('--------------------')
# Out:
# 3.3333333333333335
# ['지영']
# 지영 5
# --------------------
# 5.5
# ['영희']
# 영희 7
# --------------------

# %%
a=int(input())
b=list(input().split())
d={} #전체 학생
s_n=int(input())
s_m=list(input().split())
n=[] #미제출 학생
for i in b:
  if i in s_m:
    d[i]= True
  else:
    d[i]=False
    n.append(i)
print(f'제출여부 {d}')
print(f'미제출 학생{n}')
print(f'제출자 수: {len(b)-len(n)}')
print(f'미제출자 수: {len(n)}')
# Out:
# 제출여부 {'민수': True, '지영': False, '철수': False, '영희': True, '수진': True}
# 미제출 학생['지영', '철수']
# 제출자 수: 3
# 미제출자 수: 2
