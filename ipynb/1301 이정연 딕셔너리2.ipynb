# %%
dict1 = dict({'자바':80,'PHP':90,'HTML':70})
print(dict1['자바'])
print(dict1.get('자바'))
# print(dict1['파이썬'])
print(dict1.get('파이썬'))

dict1['파이썬']=100
dict1['자바']=100

del dict1['PHP']
print(dict1)

print(dict1.keys())
print(dict1.values())
print(dict1.items())

print('HTML' in dict1)


dict1.clear()
print(dict1)
# Out:
# 80
# 80
# None
# {'자바': 100, 'HTML': 70, '파이썬': 100}
# dict_keys(['자바', 'HTML', '파이썬'])
# dict_values([100, 70, 100])
# dict_items([('자바', 100), ('HTML', 70), ('파이썬', 100)])
# True
# {}
